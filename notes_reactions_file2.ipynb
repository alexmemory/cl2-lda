# %% [markdown]
# # Reactions file from Oct 3, 2012 debate

# %% [markdown]
# We are looking at the debates reaction data for the Oct 3 2012 presidential debate.This version uses an external clean up function to prepare the tables.

# %%
import pandasfrom pandas.tools.plotting import scatter_matriximport randomimport reactions as rc

# %% [markdown]
# Read in the Oct3 2012 debate file.

# %%
# %time parts = rc.split_reactions_file('data/reactions_oct3_4project.csv')
# Out:
# CPU times: user 4.26 s, sys: 0.36 s, total: 4.62 sWall time: 4.62 s

# %% [markdown]
# ##The questionnaire part

# %%
questionnaire = parts['questionnaire']

# %%
len(questionnaire)
# Out:
# 3767

# %% [markdown]
# ### Questionnaire: demographics

# %% [markdown]
# We look at the demographic parts of the questionnaire.

# %%
demos = parts['quest_demographic']

# %%
demos.head()
# Out:
#      gender_16     age_17   family_income_18          race_19  \0       female      18-24  $100,000 or above  white/caucasian   62        male      18-24    $25,000-$49,999         hispanic   70        male      18-24  $100,000 or above        no answer   105  no answer  no answer          no answer        no answer   121     female      18-24          no answer  white/caucasian                           religion_20 christian_21   state_22  0     christian (see next question)     catholic         pa  62    christian (see next question)     catholic         tx  70   none (e.g., atheist, agnostic)    no answer         tx  105                       no answer    no answer  no answer  121   christian (see next question)     catholic         tx

# %%
demos.describe()
# Out:
#        gender_16 age_17   family_income_18          race_19  \count       3724   3724               3724             3724   unique         3      6                  6                6   top         male  18-24  $100,000 or above  white/caucasian   freq        1485   2511               1014             1890                             religion_20 christian_21   state_22  count                            3724         3724       3724  unique                              6            6         86  top     christian (see next question)    no answer  no answer  freq                             1764         2062        769

# %%
demos.gender_16.value_counts().plot(kind='barh')

# %%
demos.age_17.value_counts().plot(kind='barh')

# %%
demos.family_income_18.value_counts().plot(kind='barh')

# %%
demos.race_19.value_counts().plot(kind='barh')

# %%
demos.religion_20.value_counts().plot(kind='barh')

# %%
demos.christian_21.value_counts().plot(kind='barh')

# %%
demos.state_22.value_counts()[:25].plot(kind='barh')

# %% [markdown]
# ### Questionnaire: political

# %% [markdown]
# Now the part of the questionnaire with political questions.

# %%
pols = parts['quest_political']

# %%
pols.head(2)
# Out:
#                         party_1  political_views_2 candidate_choice_3  \0   closest to republican party                 73             romney   62  closest to democratic party                 20              obama       confidence_in_choice_4  likely_to_vote_5  immigration_priority_6  \0                      100               100                      72   62                     100               100                      50       health_care_priority_7  foreign_policy_priority_8  abortion_priority_9  \0                       99                        100                  100   62                      99                        100                   50       economy_priority_10  immigration_party_11  health_care_party_12  \0                   100                    68                   100   62                   91                    24                     9       foreign_policy_party_13  abortion_party_14  economy_party_15  interested_23  \0                       100                 56               100             78   62                       23                 50                27             71      news_sources_24  economy_candidate_27  foreign_policy_candidate_28  \0         internet                   NaN                          100   62             cnn                   NaN                           28       candidate_preferred_29  0                      NaN  62                     NaN

# %%
pols.describe()
# Out:
#        political_views_2  confidence_in_choice_4  likely_to_vote_5  \count        3733.000000             3733.000000       3733.000000   mean           42.709081               73.250737         84.203054   std            23.909944               21.605615         28.824180   min             0.000000                0.000000          0.000000   25%            24.000000               51.000000         83.000000   50%            45.000000               75.000000         99.000000   75%            56.000000               95.000000        100.000000   max           100.000000              100.000000        100.000000          immigration_priority_6  health_care_priority_7  foreign_policy_priority_8  \count             3733.000000             3733.000000                3733.000000   mean                62.512992               76.524779                  73.201179   std                 22.907455               19.360440                  19.985163   min                  0.000000                0.000000                   0.000000   25%                 50.000000               65.000000                  60.000000   50%                 64.000000               77.000000                  74.000000   75%                 77.000000               95.000000                  90.000000   max                100.000000              100.000000                 100.000000          abortion_priority_9  economy_priority_10  immigration_party_11  \count          3733.000000          3733.000000           3733.000000   mean             60.287972            86.720064             40.696491   std              30.642562            15.808765             28.894063   min               0.000000             0.000000              0.000000   25%              43.000000            77.000000             17.000000   50%              63.000000            93.000000             43.000000   75%              87.000000           100.000000             56.000000   max             100.000000           100.000000            100.000000          health_care_party_12  foreign_policy_party_13  abortion_party_14  \count           3733.000000              3733.000000        3733.000000   mean              37.153764                45.252344          33.961693   std               29.926490                27.658015          31.482031   min                0.000000                 0.000000           0.000000   25%               10.000000                25.000000           2.000000   50%               34.000000                50.000000          28.000000   75%               50.000000                61.000000          50.000000   max              100.000000               100.000000         100.000000          economy_party_15  interested_23  economy_candidate_27  \count       3733.000000    3724.000000            517.000000   mean          47.386017      66.429646             39.232108   std           30.168332      23.810834             32.132844   min            0.000000       0.000000              0.000000   25%           24.000000      50.000000             11.000000   50%           50.000000      65.000000             33.000000   75%           69.000000      87.000000             62.000000   max          100.000000     100.000000            100.000000          foreign_policy_candidate_28  candidate_preferred_29  count                  1089.000000             2118.000000  mean                     40.010101               33.658640  std                      29.003944               33.568972  min                       0.000000                0.000000  25%                      17.000000                1.000000  50%                      42.000000               24.000000  75%                      51.000000               52.000000  max                     100.000000              100.000000

# %%
pols.party_1.value_counts().plot(kind='barh')

# %%
pols.candidate_choice_3.value_counts().plot(kind='barh')

# %%
pols.news_sources_24.value_counts()[:25].plot(kind='barh')

# %% [markdown]
# ### Interpreting questionnaire answers that are given with a slider

# %% [markdown]
# #### What does a high or low value in the party-specific slider questions mean?

# %%
# %time scatter(pols.political_views_2, pols.candidate_preferred_29, alpha=1.0/20)
# Out:
# CPU times: user 0.09 s, sys: 0.00 s, total: 0.10 sWall time: 0.09 s

# %% [markdown]
# Clearly the political views slider correlates with the candidate slider, which suggests that the conservative choice is always on one side and the liberal on the other, for example.

# %%
p2 = pols[[c.strip() for c in """party_1political_views_2foreign_policy_party_13abortion_party_14economy_party_15economy_candidate_27foreign_policy_candidate_28candidate_preferred_29""".split('\n') if not c.strip()=='']].groupby('party_1')

# %%
p2.head(2)
# Out:
#                                                       party_1  political_views_2  \party_1                                                                            closest to democratic party 62    closest to democratic party                 20                               70    closest to democratic party                  1   closest to republican party 0     closest to republican party                 73                               126   closest to republican party                 66   independent                 581                   independent                 23                               1327                  independent                 50   lean democrat               105                 lean democrat                 34                               262                 lean democrat                 26   lean republican             168               lean republican                 63                               187               lean republican                 61   no answer                   121                     no answer                 58                               1921                    no answer                 50                                     foreign_policy_party_13  abortion_party_14  \party_1                                                                        closest to democratic party 62                         23                 50                               70                          4                  3   closest to republican party 0                         100                 56                               126                        75                 45   independent                 581                         5                  5                               1327                       25                100   lean democrat               105                        31                 10                               262                        50                 15   lean republican             168                        78                 46                               187                        50                 51   no answer                   121                        79                  0                               1921                       50                 50                                     economy_party_15  economy_candidate_27  \party_1                                                                    closest to democratic party 62                  27                   NaN                               70                   8                   NaN   closest to republican party 0                  100                   NaN                               126                 94                   NaN   independent                 581                  4                   NaN                               1327                50                   NaN   lean democrat               105                 21                   NaN                               262                 38                   NaN   lean republican             168                 90                   NaN                               187                 99                   NaN   no answer                   121                 27                   NaN                               1921                50                   NaN                                     foreign_policy_candidate_28  \party_1                                                         closest to democratic party 62                             28                               70                              4   closest to republican party 0                             100                               126                            86   independent                 581                            50                               1327                           30   lean democrat               105                             0                               262                            22   lean republican             168            ...

# %%
p2.aggregate(np.average)
# Out:
#                              political_views_2  foreign_policy_party_13  \party_1                                                                   closest to democratic party          24.236780                28.525651   closest to republican party          77.154489                76.695198   independent                          46.262542                47.566890   lean democrat                        35.481434                38.693982   lean republican                      62.104364                64.049336   no answer                            45.222222                44.802469                                abortion_party_14  economy_party_15  \party_1                                                            closest to democratic party          17.898974         25.176006   closest to republican party          66.033403         84.870564   independent                          37.811037         52.586957   lean democrat                        26.436620         39.733675   lean republican                      49.759013         72.485769   no answer                            36.913580         45.209877                                economy_candidate_27  foreign_policy_candidate_28  \party_1                                                                          closest to democratic party                   NaN                          NaN   closest to republican party                   NaN                          NaN   independent                                   NaN                          NaN   lean democrat                                 NaN                          NaN   lean republican                               NaN                          NaN   no answer                                     NaN                          NaN                                candidate_preferred_29  party_1                                              closest to democratic party                     NaN  closest to republican party                     NaN  independent                                     NaN  lean democrat                                   NaN  lean republican                                 NaN  no answer                                       NaN

# %% [markdown]
# Clearly, the slider was set such that the high number (close to 100) was the republican choice and the low number (close to 0) was the democratic choice.

# %% [markdown]
# ## The reactions part

# %%
react = parts['reactions']

# %%
react[['Time','Reaction_who','Reaction_what']].head(2)
# Out:
#                       Time Reaction_who Reaction_what0  2012-10-04 01:03:50.179    Moderator         Agree1  2012-10-04 01:05:17.907        Obama          Spin

# %%
react.Reaction_who.value_counts().plot(kind='barh')

# %%
react.Reaction_what.value_counts().plot(kind='barh')

# %%
react.UserID.value_counts()[:50].plot(kind='barh')
